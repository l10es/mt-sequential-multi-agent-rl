# %% [markdown]
# - [Open with Colab](https://colab.research.google.com/github/Danboruya/my-research-hub/blob/master/Cartpole-v0-pytorch.ipynb)

# %% [markdown]
# # CartPorle-v0 implement using PyTorch

# %% [markdown]
# ## Running environment setup

# %%
# !apt-get install xvfb ffmpeg
# !pip install -q gym imageio PILLOW pyvirtualdisplay 'gym[atari]' JSAnimation
# !pip install -U 'pyglet==1.3.2' pyopengl scipy
# !apt-get install -y cmake zlib1g-dev libjpeg-dev xvfb ffmpeg xorg-dev python-opengl libboost-all-dev libsdl2-dev swig freeglut3-dev
# !pip install 'gym[atari]' opencv-python pillow h5py pyyaml hyperdash pyvirtualdisplay
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 4 not upgraded.
# Need to get 783 kB of archives.
# After this operation, 2,266 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.3 [783 kB]
# Fetched 783 kB in 3s (302 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 131289 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.3_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.3) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.3) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
#   Building wheel for JSAnimation (setup.py) ... done
# Collecting pyglet==1.3.2
#   Downloading https://files.pythonhosted.org/packages/1c/fc/dad5eaaab68f0c21e2f906a94ddb98175662cc5a654eee404d59554ce0fa/pyglet-1.3.2-py2.py3-none-any.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 44.6MB/s
# Requirement already up-to-date: pyopengl in /usr/local/lib/python3.6/dist-packages (3.1.0)
# Requirement already up-to-date: scipy in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from pyglet==1.3.2) (0.16.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from scipy) (1.16.4)
# Installing collected packages: pyglet
#   Found existing installation: pyglet 1.4.1
#     Uninstalling pyglet-1.4.1:
#       Successfully uninstalled pyglet-1.4.1
# Successfully installed pyglet-1.3.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2).
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# freeglut3-dev is already the newest version (2.8.1-3).
# freeglut3-dev set to manually installed.
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# xvfb is already the newest version (2:1.19.6-1ubuntu4.3).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   gir1.2-ibus-1.0 libcapnp-0.6.1 libdbus-1-dev libdmx-dev libdmx1
#   libfontenc-dev libfs-dev libfs6 libibus-1.0-5 libibus-1.0-dev
#   libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libpciaccess-dev libpixman-1-dev libprotobuf-dev libprotobuf-lite10
#   libpulse-dev libpulse-mainloop-glib0 libsndio-dev libudev-dev libxaw7-dev
#   libxcomposite-dev libxcursor-dev libxfont-dev libxinerama-dev
#   libxkbcommon-dev libxkbfile-dev libxmuu-dev libxpm-dev libxrandr-dev
#   libxres-dev libxres1 libxtst-dev libxv-dev libxvmc-dev libxvmc1
#   libxxf86dga-dev libxxf86dga1 mir-client-platform-mesa-dev swig3.0
#   x11proto-composite-dev x11proto-dri2-dev x11proto-fonts-dev x11proto-gl-dev
#   x11proto-randr-dev x11proto-record-dev x11proto-render-dev
#   x11proto-resource-dev x11proto-xf86bigfont-dev x11proto-xf86dga-dev
#   x11proto-xinerama-dev xserver-xorg-dev
# Suggested packages:
#   libxaw-doc libgle3 swig-doc swig-examples swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   gir1.2-ibus-1.0 libcapnp-0.6.1 libdbus-1-dev libdmx-dev libdmx1
#   libfontenc-dev libfs-dev libfs6 libibus-1.0-5 libibus-1.0-dev
#   libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libpciaccess-dev libpixman-1-dev libprotobuf-dev libprotobuf-lite10
#   libpulse-dev libpulse-mainloop-glib0 libsdl2-dev libsndio-dev libudev-dev
#   libxaw7-dev libxcomposite-dev libxcursor-dev libxfont-dev libxinerama-dev
#   libxkbcommon-dev libxkbfile-dev libxmuu-dev libxpm-dev libxrandr-dev
#   libxres-dev libxres1 libxtst-dev libxv-dev libxvmc-dev libxvmc1
#   libxxf86dga-dev libxxf86dga1 mir-client-platform-mesa-dev python-opengl swig
#   swig3.0 x11proto-composite-dev x11proto-dri2-dev x11proto-fonts-dev
#   x11proto-gl-dev x11proto-randr-dev x11proto-record-dev x11proto-render-dev
#   x11proto-resource-dev x11proto-xf86bigfont-dev x11proto-xf86dga-dev
#   x11proto-xinerama-dev xorg-dev xserver-xorg-dev
# 0 upgraded, 63 newly installed, 0 to remove and 4 not upgraded.
# Need to get 6,814 kB of archives.
# After this operation, 42.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdmx1 amd64 1:1.1.3-1 [10.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libibus-1.0-5 amd64 1.5.17-3ubuntu4 [134 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-ibus-1.0 amd64 1.5.17-3ubuntu4 [66.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcapnp-0.6.1 amd64 0.6.1-1ubuntu1 [658 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdbus-1-dev amd64 1.12.2-1ubuntu1.1 [165 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 libdmx-dev amd64 1:1.1.3-1 [34.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfontenc-dev amd64 1:1.1.3-1 [13.8 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfs6 amd64 2:1.0.7-1 [22.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-fonts-dev all 2018.4-4 [2,620 B]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfs-dev amd64 2:1.0.7-1 [26.8 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libibus-1.0-dev amd64 1.5.17-3ubuntu4 [145 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore1 amd64 0.31.1-0ubuntu1 [26.5 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon7 amd64 0.31.1-0ubuntu1 [73.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirprotobuf3 amd64 0.31.1-0ubuntu1 [127 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient9 amd64 0.31.1-0ubuntu1 [199 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore-dev amd64 0.31.1-0ubuntu1 [21.7 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon-dev amd64 0.8.0-1ubuntu0.1 [308 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon-dev amd64 0.31.1-0ubuntu1 [13.9 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie2 amd64 0.31.1-0ubuntu1 [19.7 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie-dev amd64 0.31.1-0ubuntu1 [4,392 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient-dev amd64 0.31.1-0ubuntu1 [47.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-mainloop-glib0 amd64 1:11.1-1ubuntu7.2 [22.1 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-dev amd64 1:11.1-1ubuntu7.2 [81.5 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio-dev amd64 1.1.0-3 [13.3 kB]
# Err:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev-dev amd64 237-3ubuntu10.24
#   404  Not Found [IP: 91.189.88.31 80]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-dev amd64 2.0.8+dfsg1-1ubuntu1.18.04.3 [684 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxpm-dev amd64 1:3.5.12-1 [87.4 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxaw7-dev amd64 2:1.0.13-1 [231 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-composite-dev all 1:2018.4-4 [2,620 B]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite-dev amd64 1:0.4.4-2 [9,136 B]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxfont-dev amd64 1:2.0.3-1 [118 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxkbfile-dev amd64 1:1.0.9-2 [74.3 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxmuu-dev amd64 2:1.1.2-2 [7,056 B]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxres1 amd64 2:1.2.0-2 [7,716 B]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-resource-dev all 2018.4-4 [2,620 B]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxres-dev amd64 2:1.2.0-2 [8,136 B]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-record-dev all 2018.4-4 [2,620 B]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxtst-dev amd64 2:1.2.3-1 [15.2 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxvmc1 amd64 2:1.0.10-1 [13.7 kB]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxvmc-dev amd64 2:1.0.10-1 [21.3 kB]
# Get:51 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xf86dga-dev all 2018.4-4 [2,624 B]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga-dev amd64 2:1.1.4-1 [17.6 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic/main amd64 mir-client-platform-mesa-dev amd64 0.31.1-0ubuntu1 [11.0 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig3.0 amd64 3.0.12-1 [1,094 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/universe amd64 swig amd64 3.0.12-1 [6,460 B]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-dri2-dev all 2018.4-4 [2,620 B]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-gl-dev all 2018.4-4 [2,612 B]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-render-dev all 2:2018.4-4 [2,620 B]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xf86bigfont-dev all 2018.4-4 [2,628 B]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpciaccess-dev amd64 0.14-1 [20.2 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-xorg-dev amd64 2:1.19.6-1ubuntu4.3 [198 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xorg-dev all 1:7.7+19ubuntu7.1 [4,300 B]
# Fetched 6,795 kB in 7s (1,045 kB/s)
# E: Failed to fetch http://archive.ubuntu.com/ubuntu/pool/main/s/systemd/libudev-dev_237-3ubuntu10.24_amd64.deb  404  Not Found [IP: 91.189.88.31 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# Requirement already satisfied: gym[atari] in /usr/local/lib/python3.6/dist-packages (0.10.11)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (3.4.5.20)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (4.3.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.8.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (3.13)
# Collecting hyperdash
#   Downloading https://files.pythonhosted.org/packages/fb/a1/2606aa8a8c3bf083cb305dba3164cb00285f97db34080d63c22b6c413175/hyperdash-0.15.3.tar.gz
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.6/dist-packages (0.2.4)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (2.21.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (1.3.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (1.16.4)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (1.3.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (1.12.0)
# Requirement already satisfied: PyOpenGL; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (3.1.0)
# Requirement already satisfied: atari-py>=0.1.4; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]) (0.1.15)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow) (0.46)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from hyperdash) (3.0.3)
# Requirement already satisfied: EasyProcess in /usr/local/lib/python3.6/dist-packages (from pyvirtualdisplay) (0.2.7)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym[atari]) (2.8)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym[atari]) (0.16.0)
# Requirement already satisfied: text-unidecode==1.2 in /usr/local/lib/python3.6/dist-packages (from python-slugify->hyperdash) (1.2)
# Building wheels for collected packages: hyperdash
#   Building wheel for hyperdash (setup.py) ... done
#   Created wheel for hyperdash: filename=hyperdash-0.15.3-cp36-none-any.whl size=28554 sha256=5cec17e57c2f2455041b5191504be01a1e52db8149a486b42f31c3a5a3abf94a
#   Stored in directory: /root/.cache/pip/wheels/62/5f/af/bbcaeb6570e4904c14fb4c1b70fee559a3788182ce4d104ce7
# Successfully built hyperdash
# Installing collected packages: hyperdash
# Successfully installed hyperdash-0.15.3

# %%
# !cp xdpyinfo /usr/bin/
# !cp libXxf86dga.* /usr/lib/x86_64-linux-gnu/
# !chmod +x /usr/bin/xdpyinfo

# %% [markdown]
# ## Package import

# %%
# %matplotlib inline

import random
import os

import numpy as np
import matplotlib.pyplot as plt
import gym
import torch
import torch.nn.functional as F
import pyvirtualdisplay
import base64
import imageio
import IPython
import matplotlib
import matplotlib.pyplot as plt
import PIL.Image
import pyvirtualdisplay


from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from pyvirtualdisplay import Display
from IPython.display import display
from collections import namedtuple

# %%
# display = Display(visible=0, size=(1024, 768))
# display.start()
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()
os.environ["DISPLAY"] = ":" + str(display.display) + "." + str(display.screen)

# %%
def display_frames_as_gif(frames, file_name):
    # plt.figure(figsize=(frames[0].shape[1] / 72.0, frames[0].shape[0] / 72.0), dpi=72)
    patch = plt.imshow(frames[0])
    # plt.axes('off')
    
    def animate(i):
        patch.set_data(frames[i])
    
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    
    anim.save(file_name)
    display(display_animation(anim, default_mode='loop'))

# %%
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %% [markdown]
# ## Hyper parameters

# %%
ENV = 'CartPole-v0' # @param
GAMMA = 0.99 # @param
MAX_STEPS = 200 #@param
NUM_EPISODES = 500 # @param
BATCH_SIZE = 32 # @param
CAPACITY = 10000 # @param
FILE_NAME = "test.mp4" # @param
LEARNING_RATE = 0.0001 # @param
random.seed(0)

# %% [markdown]
# ## Requiermented modules

# %%
class ReplayMemory:
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.index = 0
    
    
    def push(self, state, action, next_state, reward):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        
        self.memory[self.index] = Transition(state, action, next_state, reward)
        self.index = (self.index + 1) % self.capacity
        
    
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    
    def __len__(self):
        return len(self.memory)

# %%
class AgentCore:
    def __init__(self, num_state, num_actions):
        self.num_actions = num_actions
        self.memory = ReplayMemory(CAPACITY)
        
        # Agent neural network
        self.model = torch.nn.Sequential()
        self.model.add_module('fc0', torch.nn.Linear(num_state, 32))
        self.model.add_module('relu0', torch.nn.ReLU())
        self.model.add_module('fc1', torch.nn.Linear(32, 32))
        self.model.add_module('relu1', torch.nn.ReLU())
        self.model.add_module('fc2', torch.nn.Linear(32, num_actions))
        
        print(self.model)
        
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=LEARNING_RATE)
        
    
    def replay(self):
        if len(self.memory) < BATCH_SIZE:
            return

        transitions = self.memory.sample(BATCH_SIZE)
        batch = Transition(*zip(*transitions))
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])

        self.model.eval()
        state_action_values = self.model(state_batch).gather(1, action_batch)
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, batch.next_state)))
        next_state_values = torch.zeros(BATCH_SIZE)
        next_state_values[non_final_mask] = self.model(non_final_next_states).max(1)[0].detach()
        expected_state_action_values = reward_batch + GAMMA * next_state_values

        self.model.train()
        loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
    
    
    def decide_action(self, state, episode):
        epsilon = 0.5 * (1 / (episode + 1))
        
        if epsilon <= np.random.uniform(0, 1):
            self.model.eval()
            with torch.no_grad():
                action = self.model(state).max(1)[1].view(1, 1)
        else:
            action = torch.LongTensor([[random.randrange(self.num_actions)]])
        return action

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        self.core = AgentCore(num_states, num_actions)
        
        
    def update_q_function(self):
        self.core.replay()
    
    
    def get_action(self, state, episode):
        action = self.core.decide_action(state, episode)
        return action
    
    
    def memorize(self, state, action, next_state, reward):
        self.core.memory.push(state, action, next_state, reward)

# %%
class Environment:

    def __init__(self):
        self.env = gym.make(ENV)
        num_states = self.env.observation_space.shape[0]
        num_actions = self.env.action_space.n
        self.agent = Agent(num_states, num_actions)

        
    def run(self):
        episode_10_list = np.zeros(10)
        complete_episodes = 0
        episode_final = False
        frames = []

        for episode in range(NUM_EPISODES):
            observation = self.env.reset()

            state = observation
            state = torch.from_numpy(state).type(torch.FloatTensor)
            state = torch.unsqueeze(state, 0)

            for step in range(MAX_STEPS):
                if episode_final is True:
                    frames.append(self.env.render(mode='rgb_array'))

                action = self.agent.get_action(state, episode)
                next_observation, _, done, _ = self.env.step(action.item())

                if done:
                    next_state = None

                    episode_10_list = np.hstack((episode_10_list[1:], step + 1))

                    if step < 195:
                        reward = torch.FloatTensor([-1.0])
                        complete_episodes = 0
                    else:
                        reward = torch.FloatTensor([1.0])
                        complete_episodes = complete_episodes + 1
                else:
                    reward = torch.FloatTensor([0.0])
                    next_state = next_observation
                    next_state = torch.from_numpy(next_state).type(torch.FloatTensor)
                    next_state = torch.unsqueeze(next_state, 0)

                self.agent.memorize(state, action, next_state, reward)
                self.agent.update_q_function()
                state = next_state

                if done:
                    print('%d Episode: Finished after %d steps：10 step average = %.1lf' % (episode, step + 1, episode_10_list.mean()))
                    break

            if episode_final is True:
                display_frames_as_gif(frames, FILE_NAME)
                break

            if complete_episodes >= 10:
                print("10 consecutive successes")
                episode_final = True

# %% [markdown]
# ## Evaluation of the model

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Sequential(
#   (fc0): Linear(in_features=4, out_features=32, bias=True)
#   (relu0): ReLU()
#   (fc1): Linear(in_features=32, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 12 steps：10 step average = 1.2
# 1 Episode: Finished after 12 steps：10 step average = 2.4
# 2 Episode: Finished after 10 steps：10 step average = 3.4
# 3 Episode: Finished after 10 steps：10 step average = 4.4
# 4 Episode: Finished after 10 steps：10 step average = 5.4
# 5 Episode: Finished after 9 steps：10 step average = 6.3
# 6 Episode: Finished after 10 steps：10 step average = 7.3
# 7 Episode: Finished after 8 steps：10 step average = 8.1
# 8 Episode: Finished after 9 steps：10 step average = 9.0
# 9 Episode: Finished after 10 steps：10 step average = 10.0
# 10 Episode: Finished after 10 steps：10 step average = 9.8
# 11 Episode: Finished after 10 steps：10 step average = 9.6
# 12 Episode: Finished after 10 steps：10 step average = 9.6
# 13 Episode: Finished after 10 steps：10 step average = 9.6
# 14 Episode: Finished after 9 steps：10 step average = 9.5
# 15 Episode: Finished after 8 steps：10 step average = 9.4
# 16 Episode: Finished after 9 steps：10 step average = 9.3
# 17 Episode: Finished after 11 steps：10 step average = 9.6
# 18 Episode: Finished after 8 steps：10 step average = 9.5
# 19 Episode: Finished after 11 steps：10 step average = 9.6
# 20 Episode: Finished after 10 steps：10 step average = 9.6
# 21 Episode: Finished after 9 steps：10 step average = 9.5
# 22 Episode: Finished after 10 steps：10 step average = 9.5
# 23 Episode: Finished after 11 steps：10 step average = 9.6
# 24 Episode: Finished after 11 steps：10 step average = 9.8
# 25 Episode: Finished after 13 steps：10 step average = 10.3
# 26 Episode: Finished after 10 steps：10 step average = 10.4
# 27 Episode: Finished after 11 steps：10 step average = 10.4
# 28 Episode: Finished after 15 steps：10 step average = 11.1
# 29 Episode: Finished after 10 steps：10 step average = 11.0
# 30 Episode: Finished after 10 steps：10 step average = 11.0
# 31 Episode: Finished after 11 steps：10 step average = 11.2
# 32 Episode: Finished after 11 steps：10 step average = 11.3
# 33 Episode: Finished after 13 steps：10 step average = 11.5
# 34 Episode: Finished after 11 steps：10 step average = 11.5
# 35 Episode: Finished after 11 steps：10 step average = 11.3
# 36 Episode: Finished after 13 steps：10 step average = 11.6
# 37 Episode: Finished after 12 steps：10 step average = 11.7
# 38 Episode: Finished after 11 steps：10 step average = 11.3
# 39 Episode: Finished after 10 steps：10 step average = 11.3
# 40 Episode: Finished after 11 steps：10 step average = 11.4
# 41 Episode: Finished after 11 steps：10 step average = 11.4
# 42 Episode: Finished after 13 steps：10 step average = 11.6
# 43 Episode: Finished after 11 steps：10 step average = 11.4
# 44 Episode: Finished after 13 steps：10 step average = 11.6
# 45 Episode: Finished after 13 steps：10 step average = 11.8
# 46 Episode: Finished after 12 steps：10 step average = 11.7
# 47 Episode: Finished after 12 steps：10 step average = 11.7
# 48 Episode: Finished after 13 steps：10 step average = 11.9
# 49 Episode: Finished after 13 steps：10 step average = 12.2
# 50 Episode: Finished after 13 steps：10 step average = 12.4
# 51 Episode: Finished after 13 steps：10 step average = 12.6
# 52 Episode: Finished after 12 steps：10 step average = 12.5
# 53 Episode: Finished after 13 steps：10 step average = 12.7
# 54 Episode: Finished after 15 steps：10 step average = 12.9
# 55 Episode: Finished after 12 steps：10 step average = 12.8
# 56 Episode: Finished after 15 steps：10 step average = 13.1
# 57 Episode: Finished after 17 steps：10 step average = 13.6
# 58 Episode: Finished after 15 steps：10 step average = 13.8
# 59 Episode: Finished after 18 steps：10 step average = 14.3
# 60 Episode: Finished after 17 steps：10 step average = 14.7
# 61 Episode: Finished after 21 steps：10 step average = 15.5
# 62 Episode: Finished after 16 steps：10 step average = 15.9
# 63 Episode: Finished after 19 steps：10 step average = 16.5
# 64 Episode: Finished after 23 steps：10 step average = 17.3
# 65 Episode: Finished after 22 steps：10 step average = 18.3
# 66 Episode: Finished after 33 steps：10 step average = 20.1
# 67 Episode: Finished after 45 steps：10 step average = 22.9
# 68 Episode: Finished after 37 steps：10 step average = 25.1
# 69 Episode: Finished after 46 steps：10 step average = 27.9
# 70 Episode: Finished after 42 steps：10 step average = 30.4
# 71 Episode: Finished after 51 steps：10 step average = 33.4
# 72 Episode: Finished after 56 steps：10 step average = 37.4
# 73 Episode: Finished after 97 steps：10 step average = 45.2
# 74 Episode: Finished after 93 steps：10 step average = 52.2
# 75 Episode: Finished after 82 steps：10 step average = 58.2
# 76 Episode: Finished after 91 steps：10 step average = 64.0
# 77 Episode: Finished after 103 steps：10 step average = 69.8
# 78 Episode: Finished after 103 steps：10 step average = 76.4
# 79 Episode: Finished after 106 steps：10 step average = 82.4
# 80 Episode: Finished after 97 steps：10 step average = 87.9
# 81 Episode: Finished after 86 steps：10 step average = 91.4
# 82 Episode: Finished after 83 steps：10 step average = 94.1
# 83 Episode: Finished after 102 steps：10 step average = 94.6
# 84 Episode: Finished after 153 steps：10 step average = 100.6
# 85 Episode: Finished after 145 steps：10 step average = 106.9
# 86 Episode: Finished after 111 steps：10 step average = 108.9
# 87 Episode: Finished after 78 steps：10 step average = 106.4
# 88 Episode: Finished after 103 steps：10 step average = 106.4
# 89 Episode: Finished after 135 steps：10 step average = 109.3
# 90 Episode: Finished after 173 steps：10 step average = 116.9
# 91 Episode: Finished after 110 steps：10 step average = 119.3
# 92 Episode: Finished after 152 steps：10 step average = 126.2
# 93 Episode: Finished after 112 steps：10 step average = 127.2
# 94 Episode: Finished after 176 steps：10 step average = 129.5
# 95 Episode: Finished after 200 steps：10 step average = 135.0
# 96 Episode: Finished after 152 steps：10 step average = 139.1
# 97 Episode: Finished after 200 steps：10 step average = 151.3
# 98 Episode: Finished after 200 steps：10 step average = 161.0
# 99 Episode: Finished after 117 steps：10 step average = 159.2
# 100 Episode: Finished after 151 steps：10 step average = 157.0
# 101 Episode: Finished after 192 steps：10 step average = 165.2
# 102 Episode: Finished after 200 steps：10 step average = 170.0
# 103 Episode: Finished after 200 steps：10 step average = 178.8
# 104 Episode: Finished after 200 steps：10 step average = 181.2
# 105 Episode: Finished after 200 steps：10 step average = 181.2
# 106 Episode: Finished after 160 steps：10 step average = 182.0
# 107 Episode: Finished after 200 steps：10 step average = 182.0
# 108 Episode: Finished after 200 steps：10 step average = 182.0
# 109 Episode: Finished after 200 steps：10 step average = 190.3
# 110 Episode: Finished after 200 steps：10 step average = 195.2
# 111 Episode: Finished after 200 steps：10 step average = 196.0
# 112 Episode: Finished after 200 steps：10 step average = 196.0
# 113 Episode: Finished after 200 steps：10 step average = 196.0
# 114 Episode: Finished after 200 steps：10 step average = 196.0
# 115 Episode: Finished after 200 steps：10 step average = 196.0
# 116 Episode: Finished after 200 steps：10 step average = 200.0
# 10 consecutive successes
# 117 Episode: Finished after 200 steps：10 step average = 200.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-7dfab0e69a06> in <module>()
#       1 cartpole_env = Environment()
# ----> 2 cartpole_env.run()
#
# <ipython-input-11-218de4afca57> in run(self)
#      54
#      55             if episode_final is True:
# ---> 56                 display_frames_as_gif(frames, FILE_NAME)
#      57                 break
#      58
#
# <ipython-input-5-865f7f6e5f91> in display_frames_as_gif(frames, file_name)
#      10
#      11     anim.save(file_name)
# ---> 12     display(display_animation(anim, default_mode='loop'))
#
# TypeError: 'Display' object is not callable

# %% [markdown]
# ## Video visualization

# %%
def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
        <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return IPython.display.HTML(tag)

# %%
embed_mp4(FILE_NAME)
# Out:
#     <video width="640" height="480" controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>
