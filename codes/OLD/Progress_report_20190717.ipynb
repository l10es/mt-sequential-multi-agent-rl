# %% [markdown]
# # Progress Report 2019-07-17
#
# * 論文調査
#     - [Lu Wang, Wei Zhang, Xiaofeng He, Hongyuan Zha, "Supervised Reinforcement Learning with Recurrent Neural Network for Dynamic Treatment Recommendation",  ACM SIGKDD Conference on Knowledge Discovery and Data Mining conference, 2018](https://arxiv.org/abs/1807.01473)
#     - [Christian Buck, Jannis Bulian, Massimiliano Ciaramita, Wojciech Gajewski, Andrea Gesmundo, Neil Houlsby, Wei Wang, "Ask the Right Questions: Active Question Reformulation with Reinforcement Learning", Sixth International Conference on Learning Representations (ICLR), 2018](https://arxiv.org/abs/1705.07830)
# * Reword with penalty policy
#     - 既知情報は*If-Then*形式のクラシファイアセットみたいにしても良い? <- 管理がしやすい
#     - DB形式にしてQ-Aをまとめる?
#
# * Task Definition
#     - ActiveQA: 質問応答のために人工知能エージェントを強化学習で訓練する研究プロジェクト, ICLR 2018で発表，TFパッケージ化されている
#
# * Note:
#     - 強化学習 + 教師付き学習 (Reinforcement supervised learning?)
#     - 通常は知識データベースを用いてトップダウン的に学習させていく -> 未知情報に弱い
#     - 教師付き強化学習によってボトムアップ的にAgent内部の知識を構築できればその過程で未知情報への対応力を獲得できるのでは?
#     - 教師付き強化学習だと強化学習の分野から離れる?
#         + 半教師付き強化学習ではない
#         + 強化学習は良い悪いといった大まかな情報を学習するのに使う
#         + 既知情報を部分的に用いて学習の収束性・精度向上を狙う．かつ未知情報への対応力をつけたい
#         + Agents内にAgent Networkを張って相互に通信? <- 収束性が悪くなる
#         + 収束性を見ないのであれば，精度向上を狙う．あるいは未知情報対応性を見る
