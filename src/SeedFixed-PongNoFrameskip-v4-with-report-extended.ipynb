# %% [markdown]
# # DQN implementation with PyTorch using PongNoFrameskip-v4 benchmark.
#
# In this notebook, we implement Deep Q-Network (DQN), one of the rainforcement learning algorithm, using `PyTorch`.
# This code refers to [jmichaux/dqn-pytorch](https://github.com/jmichaux/dqn-pytorch).

# %% [markdown]
# ## Setup

# %%
# !apt-get install -y cmake zlib1g-dev libjpeg-dev xvfb ffmpeg xorg-dev python-opengl libboost-all-dev libsdl2-dev swig freeglut3-dev
# !pip install -U gym imageio PILLOW pyvirtualdisplay 'gym[atari]' 'pyglet==1.3.2' pyopengl scipy JSAnimation opencv-python pillow h5py pyyaml hyperdash pyvirtualdisplay hyperdash
# !apt-get install xvfb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# freeglut3-dev is already the newest version (2.8.1-3).
# freeglut3-dev set to manually installed.
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following additional packages will be installed:
#   gir1.2-ibus-1.0 libcapnp-0.6.1 libdbus-1-dev libdmx-dev libdmx1
#   libfontenc-dev libfs-dev libfs6 libibus-1.0-5 libibus-1.0-dev
#   libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libpciaccess-dev libpixman-1-dev libprotobuf-dev libprotobuf-lite10
#   libpulse-dev libpulse-mainloop-glib0 libsndio-dev libudev-dev libxaw7-dev
#   libxcomposite-dev libxcursor-dev libxfont-dev libxinerama-dev
#   libxkbcommon-dev libxkbfile-dev libxmuu-dev libxpm-dev libxrandr-dev
#   libxres-dev libxres1 libxtst-dev libxv-dev libxvmc-dev libxvmc1
#   libxxf86dga-dev libxxf86dga1 mir-client-platform-mesa-dev swig3.0
#   x11proto-composite-dev x11proto-dri2-dev x11proto-fonts-dev x11proto-gl-dev
#   x11proto-randr-dev x11proto-record-dev x11proto-render-dev
#   x11proto-resource-dev x11proto-xf86bigfont-dev x11proto-xf86dga-dev
#   x11proto-xinerama-dev xserver-xorg-dev
# Suggested packages:
#   libxaw-doc libgle3 swig-doc swig-examples swig3.0-examples swig3.0-doc
# The following NEW packages will be installed:
#   gir1.2-ibus-1.0 libcapnp-0.6.1 libdbus-1-dev libdmx-dev libdmx1
#   libfontenc-dev libfs-dev libfs6 libibus-1.0-5 libibus-1.0-dev
#   libmirclient-dev libmirclient9 libmircommon-dev libmircommon7
#   libmircookie-dev libmircookie2 libmircore-dev libmircore1 libmirprotobuf3
#   libpciaccess-dev libpixman-1-dev libprotobuf-dev libprotobuf-lite10
#   libpulse-dev libpulse-mainloop-glib0 libsdl2-dev libsndio-dev libudev-dev
#   libxaw7-dev libxcomposite-dev libxcursor-dev libxfont-dev libxinerama-dev
#   libxkbcommon-dev libxkbfile-dev libxmuu-dev libxpm-dev libxrandr-dev
#   libxres-dev libxres1 libxtst-dev libxv-dev libxvmc-dev libxvmc1
#   libxxf86dga-dev libxxf86dga1 mir-client-platform-mesa-dev python-opengl swig
#   swig3.0 x11proto-composite-dev x11proto-dri2-dev x11proto-fonts-dev
#   x11proto-gl-dev x11proto-randr-dev x11proto-record-dev x11proto-render-dev
#   x11proto-resource-dev x11proto-xf86bigfont-dev x11proto-xf86dga-dev
#   x11proto-xinerama-dev xorg-dev xserver-xorg-dev xvfb
# 0 upgraded, 64 newly installed, 0 to remove and 8 not upgraded.
# Need to get 19.1 kB/7,598 kB of archives.
# After this operation, 44.8 MB of additional disk space will be used.
# Err:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev-dev amd64 237-3ubuntu10.25
#   404  Not Found [IP: 91.189.88.162 80]
# E: Failed to fetch http://archive.ubuntu.com/ubuntu/pool/main/s/systemd/libudev-dev_237-3ubuntu10.25_amd64.deb  404  Not Found [IP: 91.189.88.162 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# Requirement already up-to-date: gym in /usr/local/lib/python3.6/dist-packages (0.14.0)
# Requirement already up-to-date: imageio in /usr/local/lib/python3.6/dist-packages (2.5.0)
# Requirement already up-to-date: PILLOW in /usr/local/lib/python3.6/dist-packages (6.1.0)
# Requirement already up-to-date: pyvirtualdisplay in /usr/local/lib/python3.6/dist-packages (0.2.4)
# Requirement already up-to-date: pyglet==1.3.2 in /usr/local/lib/python3.6/dist-packages (1.3.2)
# Requirement already up-to-date: pyopengl in /usr/local/lib/python3.6/dist-packages (3.1.0)
# Requirement already up-to-date: scipy in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already up-to-date: JSAnimation in /usr/local/lib/python3.6/dist-packages (0.1)
# Requirement already up-to-date: opencv-python in /usr/local/lib/python3.6/dist-packages (4.1.1.26)
# Requirement already up-to-date: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already up-to-date: pyyaml in /usr/local/lib/python3.6/dist-packages (5.1.2)
# Requirement already up-to-date: hyperdash in /usr/local/lib/python3.6/dist-packages (0.15.3)
# Requirement already satisfied, skipping upgrade: cloudpickle~=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym) (1.2.2)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from gym) (1.12.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym) (1.16.5)
# Requirement already satisfied, skipping upgrade: EasyProcess in /usr/local/lib/python3.6/dist-packages (from pyvirtualdisplay) (0.2.7)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from pyglet==1.3.2) (0.16.0)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from hyperdash) (2.21.0)
# Requirement already satisfied, skipping upgrade: python-slugify in /usr/local/lib/python3.6/dist-packages (from hyperdash) (3.0.3)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->hyperdash) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->hyperdash) (2019.6.16)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->hyperdash) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->hyperdash) (1.24.3)
# Requirement already satisfied, skipping upgrade: text-unidecode==1.2 in /usr/local/lib/python3.6/dist-packages (from python-slugify->hyperdash) (1.2)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 8 not upgraded.
# Need to get 0 B/783 kB of archives.
# After this operation, 2,266 kB of additional disk space will be used.
# Selecting previously unselected package xvfb.
# (Reading database ... 131183 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.3_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.3) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.3) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp /content/drive/My\ Drive/Colab\ Notebooks/MT/Utils/xdpyinfo /usr/bin/
# !cp /content/drive/My\ Drive/Colab\ Notebooks/MT/Utils/libXxf86dga.* /usr/lib/x86_64-linux-gnu/
# !chmod +x /usr/bin/xdpyinfo

# %%
# !hyperdash signup --github
# Out:
# Opening browser, please wait. If something goes wrong, press CTRL+C to cancel.
#  SSH'd into a remote machine, or just don't have access to a browser? Open this link in any browser and then copy/paste the provided access token: https://hyperdash.io/oauth/github/start?state=client_cli_manual
# Waiting for Github OAuth to complete.
# If something goes wrong, press CTRL+C to cancel.
# Access token: ybn04/JGu80iQJL5YU+qBjjMNMkCx9FRXRVE/m3d2kY=
# Successfully logged in! We also installed: zYfW8JXjr7jfEmSCNZouY368BmbAKOp1VUkGwXNX5Ck= as your default API key

# %% [markdown]
# ## Package import

# %%
import copy
from collections import namedtuple
from itertools import count
import math
import random
import numpy as np
import os
import time

import gym
from collections import deque
from hyperdash import Experiment
import cv2

import pyvirtualdisplay
import base64
import IPython

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

# %% [markdown]
# ## Hyper parameters

# %%
# Runtime settings
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")    
Transition = namedtuple('Transion', ('state', 'action', 'next_state', 'reward'))
cv2.ocl.setUseOpenCL(False)
time_stamp = str(int(time.time()))
random.seed(0)
np.random.seed(0)

# Hyper parameters
BATCH_SIZE = 32 # @param
GAMMA = 0.99 # @param
EPS_START = 1 # @param
EPS_END = 0.02 # @param
EPS_DECAY = 1000000 # @param
TARGET_UPDATE = 1000 # @param
DEFAULT_DURABILITY = 10 # @param
LEARNING_RATE = 1e-4 # @param
INITIAL_MEMORY = 10000 # @param
MEMORY_SIZE = 10 * INITIAL_MEMORY # @param

# Some settings
ENV_NAME = "PongNoFrameskip-v4" # @param
EXP_NAME = "PongNoFrameskip-v4_" + time_stamp # @param
TRAIN_LOG_FILE_NAME = ENV_NAME + "_train_" + time_stamp + ".log" # @param
TEST_LOG_FILE_NAME = ENV_NAME + "_test_" + time_stamp + ".log" # @param
RENDER = False # @param

# %% [markdown]
# ## Define the Replay memory

# %%
class ReplayMemory(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0
        
    def push(self, *args):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity
        
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)


class PrioritizedReplay(object):
    def __init__(self, capacity):
        pass

# %% [markdown]
# ## Define the DQNs
#
# Now we define the two types of DQN. One is simple q-network using 3 layers CNN. On the other one is batch normalaized 4 layers CNN.

# %%
class DQNbn(nn.Module):
    def __init__(self, in_channels=4, n_actions=14):
        """
        Initialize Deep Q Network
        Args:
            in_channels (int): number of input channels
            n_actions (int): number of outputs
        """
        super(DQNbn, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 32, kernel_size=8, stride=4)
        self.bn1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.bn2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.bn3 = nn.BatchNorm2d(64)
        self.fc4 = nn.Linear(7 * 7 * 64, 512)
        self.head = nn.Linear(512, n_actions)
        
    def forward(self, x):
        x = x.float() / 255
        x = F.relu(self.bn1(self.conv1(x)))
        x = F.relu(self.bn2(self.conv2(x)))
        x = F.relu(self.bn3(self.conv3(x)))
        x = F.relu(self.fc4(x.view(x.size(0), -1)))
        return self.head(x)


class DQN(nn.Module):
    def __init__(self, in_channels=4, n_actions=14):
        """
        Initialize Deep Q Network
        Args:
            in_channels (int): number of input channels
            n_actions (int): number of outputs
        """
        super(DQN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc4 = nn.Linear(7 * 7 * 64, 512)
        self.head = nn.Linear(512, n_actions)
        
    def forward(self, x):
        x = x.float() / 255
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc4(x.view(x.size(0), -1)))
        return self.head(x)

# %% [markdown]
# ## Define the Agent

# %%
class Agent:
    def __init__(policy_net, target_net, durability):
        self.policy_net = policy_net
        self.target_net = target_net
        self.target_net.load_state_dict(policy_net.state_dict())
        self.durability = durability
    

    def select_action(state):
        global steps_done
        sample = random.random()
        eps_threshold = EPS_END + (EPS_START - EPS_END)* \
            math.exp(-1. * steps_done / EPS_DECAY)
        steps_done += 1
        if sample > eps_threshold:
            with torch.no_grad():
                return policy_net(state.to('cuda')).max(1)[1].view(1,1)
        else:
            return torch.tensor([[random.randrange(4)]], device=device, dtype=torch.long)

    
    def optimize_model():
        if len(memory) < BATCH_SIZE:
            return
        transitions = memory.sample(BATCH_SIZE)
        """
        zip(*transitions) unzips the transitions into
        Transition(*) creates new named tuple
        batch.state - tuple of all the states (each state is a tensor)
        batch.next_state - tuple of all the next states (each state is a tensor)
        batch.reward - tuple of all the rewards (each reward is a float)
        batch.action - tuple of all the actions (each action is an int)    
        """
        batch = Transition(*zip(*transitions))
        
        actions = tuple((map(lambda a: torch.tensor([[a]], device='cuda'), batch.action))) 
        rewards = tuple((map(lambda r: torch.tensor([r], device='cuda'), batch.reward))) 

        non_final_mask = torch.tensor(
            tuple(map(lambda s: s is not None, batch.next_state)),
            device=device, dtype=torch.uint8)
        
        non_final_next_states = torch.cat([s for s in batch.next_state
                                        if s is not None]).to('cuda')
        

        state_batch = torch.cat(batch.state).to('cuda')
        action_batch = torch.cat(actions)
        reward_batch = torch.cat(rewards)
        
        state_action_values = policy_net(state_batch).gather(1, action_batch)
        
        next_state_values = torch.zeros(BATCH_SIZE, device=device)
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
        expected_state_action_values = (next_state_values * GAMMA) + reward_batch
        
        loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
        
        optimizer.zero_grad()
        loss.backward()
        for param in policy_net.parameters():
            param.grad.data.clamp_(-1, 1)
        optimizer.step()


    def get_state(obs):
        state = np.array(obs)
        state = state.transpose((2, 0, 1))
        state = torch.from_numpy(state)
        return state.unsqueeze(0)


    def get_durability():
        return self.durability
    

    def reduce_durability(value):
        self.durability = self.durability - value

# %% [markdown]
# ## Define the Environment

# %%
def make_env(env, stack_frames=True, episodic_life=True, clip_rewards=False, scale=False):
    if episodic_life:
        env = EpisodicLifeEnv(env)

    env = NoopResetEnv(env, noop_max=30)
    env = MaxAndSkipEnv(env, skip=4)
    if 'FIRE' in env.unwrapped.get_action_meanings():
        env = FireResetEnv(env)

    env = WarpFrame(env)
    if stack_frames:
        env = FrameStack(env, 4)
    if clip_rewards:
        env = ClipRewardEnv(env)
    return env

class RewardScaler(gym.RewardWrapper):

    def reward(self, reward):
        return reward * 0.1


class ClipRewardEnv(gym.RewardWrapper):
    def __init__(self, env):
        gym.RewardWrapper.__init__(self, env)

    def reward(self, reward):
        """Bin reward to {+1, 0, -1} by its sign."""
        return np.sign(reward)


class LazyFrames(object):
    def __init__(self, frames):
        """This object ensures that common frames between the observations are only stored once.
        It exists purely to optimize memory usage which can be huge for DQN's 1M frames replay
        buffers.
        This object should only be converted to numpy array before being passed to the model.
        You'd not believe how complex the previous solution was."""
        self._frames = frames
        self._out = None

    def _force(self):
        if self._out is None:
            self._out = np.concatenate(self._frames, axis=2)
            self._frames = None
        return self._out

    def __array__(self, dtype=None):
        out = self._force()
        if dtype is not None:
            out = out.astype(dtype)
        return out

    def __len__(self):
        return len(self._force())

    def __getitem__(self, i):
        return self._force()[i]

class FrameStack(gym.Wrapper):
    def __init__(self, env, k):
        """Stack k last frames.
        Returns lazy array, which is much more memory efficient.
        See Also
        --------
        baselines.common.atari_wrappers.LazyFrames
        """
        gym.Wrapper.__init__(self, env)
        self.k = k
        self.frames = deque([], maxlen=k)
        shp = env.observation_space.shape
        self.observation_space = gym.spaces.Box(low=0, high=255, shape=(shp[0], shp[1], shp[2] * k), dtype=env.observation_space.dtype)

    def reset(self):
        ob = self.env.reset()
        for _ in range(self.k):
            self.frames.append(ob)
        return self._get_ob()

    def step(self, action):
        ob, reward, done, info = self.env.step(action)
        self.frames.append(ob)
        return self._get_ob(), reward, done, info

    def _get_ob(self):
        assert len(self.frames) == self.k
        return LazyFrames(list(self.frames))


class WarpFrame(gym.ObservationWrapper):
    def __init__(self, env):
        """Warp frames to 84x84 as done in the Nature paper and later work."""
        gym.ObservationWrapper.__init__(self, env)
        self.width = 84
        self.height = 84
        self.observation_space = gym.spaces.Box(low=0, high=255,
            shape=(self.height, self.width, 1), dtype=np.uint8)

    def observation(self, frame):
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(frame, (self.width, self.height), interpolation=cv2.INTER_AREA)
        return frame[:, :, None]


class FireResetEnv(gym.Wrapper):
    def __init__(self, env=None):
        """For environments where the user need to press FIRE for the game to start."""
        super(FireResetEnv, self).__init__(env)
        assert env.unwrapped.get_action_meanings()[1] == 'FIRE'
        assert len(env.unwrapped.get_action_meanings()) >= 3

    def step(self, action):
        return self.env.step(action)

    def reset(self):
        self.env.reset()
        obs, _, done, _ = self.env.step(1)
        if done:
            self.env.reset()
        obs, _, done, _ = self.env.step(2)
        if done:
            self.env.reset()
        return obs


class EpisodicLifeEnv(gym.Wrapper):
    def __init__(self, env=None):
        """Make end-of-life == end-of-episode, but only reset on true game over.
        Done by DeepMind for the DQN and co. since it helps value estimation.
        """
        super(EpisodicLifeEnv, self).__init__(env)
        self.lives = 0
        self.was_real_done = True
        self.was_real_reset = False

    def step(self, action):
        obs, reward, done, info = self.env.step(action)
        self.was_real_done = done
        # check current lives, make loss of life terminal,
        # then update lives to handle bonus lives
        lives = self.env.unwrapped.ale.lives()
        if lives < self.lives and lives > 0:
            # for Qbert somtimes we stay in lives == 0 condtion for a few frames
            # so its important to keep lives > 0, so that we only reset once
            # the environment advertises done.
            done = True
        self.lives = lives
        return obs, reward, done, info

    def reset(self):
        """Reset only when lives are exhausted.
        This way all states are still reachable even though lives are episodic,
        and the learner need not know about any of this behind-the-scenes.
        """
        if self.was_real_done:
            obs = self.env.reset()
            self.was_real_reset = True
        else:
            # no-op step to advance from terminal/lost life state
            obs, _, _, _ = self.env.step(0)
            self.was_real_reset = False
        self.lives = self.env.unwrapped.ale.lives()
        return obs


class MaxAndSkipEnv(gym.Wrapper):
    def __init__(self, env=None, skip=4):
        """Return only every `skip`-th frame"""
        super(MaxAndSkipEnv, self).__init__(env)
        # most recent raw observations (for max pooling across time steps)
        self._obs_buffer = deque(maxlen=2)
        self._skip = skip

    def step(self, action):
        total_reward = 0.0
        done = None
        for _ in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            self._obs_buffer.append(obs)
            total_reward += reward
            if done:
                break

        max_frame = np.max(np.stack(self._obs_buffer), axis=0)

        return max_frame, total_reward, done, info

    def reset(self):
        """Clear past frame buffer and init. to first obs. from inner env."""
        self._obs_buffer.clear()
        obs = self.env.reset()
        self._obs_buffer.append(obs)
        return obs

class NoopResetEnv(gym.Wrapper):
    def __init__(self, env=None, noop_max=30):
        """Sample initial states by taking random number of no-ops on reset.
        No-op is assumed to be action 0.
        """
        super(NoopResetEnv, self).__init__(env)
        self.noop_max = noop_max
        self.override_num_noops = None
        assert env.unwrapped.get_action_meanings()[0] == 'NOOP'

    def step(self, action):
        return self.env.step(action)

    def reset(self):
        """ Do no-op action for a number of steps in [1, noop_max]."""
        self.env.reset()
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = np.random.randint(1, self.noop_max + 1)
        assert noops > 0
        obs = None
        for _ in range(noops):
            obs, _, done, _ = self.env.step(0)
            if done:
                obs = self.env.reset()
        return obs

# %%
def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END)* \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            return policy_net(state.to('cuda')).max(1)[1].view(1,1)
    else:
        return torch.tensor([[random.randrange(4)]], device=device, dtype=torch.long)

    
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    """
    zip(*transitions) unzips the transitions into
    Transition(*) creates new named tuple
    batch.state - tuple of all the states (each state is a tensor)
    batch.next_state - tuple of all the next states (each state is a tensor)
    batch.reward - tuple of all the rewards (each reward is a float)
    batch.action - tuple of all the actions (each action is an int)    
    """
    batch = Transition(*zip(*transitions))
    
    actions = tuple((map(lambda a: torch.tensor([[a]], device='cuda'), batch.action))) 
    rewards = tuple((map(lambda r: torch.tensor([r], device='cuda'), batch.reward))) 

    non_final_mask = torch.tensor(
        tuple(map(lambda s: s is not None, batch.next_state)),
        device=device, dtype=torch.uint8)
    
    non_final_next_states = torch.cat([s for s in batch.next_state
                                       if s is not None]).to('cuda')
    

    state_batch = torch.cat(batch.state).to('cuda')
    action_batch = torch.cat(actions)
    reward_batch = torch.cat(rewards)
    
    state_action_values = policy_net(state_batch).gather(1, action_batch)
    
    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch
    
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))
    
    optimizer.zero_grad()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

def get_state(obs):
    state = np.array(obs)
    state = state.transpose((2, 0, 1))
    state = torch.from_numpy(state)
    return state.unsqueeze(0)

# %% [markdown]
# ## Degine the train steps
#
# In my research, make this code multi-agent (**Note**: Multi-agent here means multiple independent agents sharing a task environment)

# %%
def train(env, n_episodes, exp, render=False):
    for episode in range(n_episodes):
        obs = env.reset()
        state = get_state(obs)
        total_reward = 0.0
        for t in count():
            action = select_action(state)

            if render:
                env.render()

            obs, reward, done, info = env.step(action)

            total_reward += reward

            if not done:
                next_state = get_state(obs)
            else:
                next_state = None

            reward = torch.tensor([reward], device=device)

            memory.push(state, action.to('cpu'), next_state, reward.to('cpu'))
            state = next_state

            if steps_done > INITIAL_MEMORY:
                optimize_model()

                if steps_done % TARGET_UPDATE == 0:
                    target_net.load_state_dict(policy_net.state_dict())

            if done:
                break
        
        exp.metric("total_reword", total_reward)
        out_str = 'Total steps: {} \t Episode/Steps: {}/{} \t Total reward: {}'.format(
            steps_done, episode, t, total_reward)
        if episode % 20 == 0:
            # print(out_str)
            out_str = str("\n" + out_str + "\n")
            exp.log(out_str)
        else:
            # print(out_str)
            exp.log(out_str)
        with open(TRAIN_LOG_FILE_NAME, 'wt') as f:
            f.write(out_str)
    env.close()
    return

# %% [markdown]
# ## Define the test steps

# %%
def test(env, n_episodes, policy, exp, render=True):
    env = gym.wrappers.Monitor(env, './videos/' + 'dqn_pong_video')
    for episode in range(n_episodes):
        obs = env.reset()
        state = get_state(obs)
        total_reward = 0.0
        for t in count():
            action = policy(state.to('cuda')).max(1)[1].view(1,1)

            if render:
                env.render()
                time.sleep(0.02)

            obs, reward, done, info = env.step(action)

            total_reward += reward

            if not done:
                next_state = get_state(obs)
            else:
                next_state = None

            state = next_state

            if done:
                out_str = "Finished Episode {} with reward {}".format(
                    episode, total_reward)
                print(out_str)
                exp.log(out_str)
                with open(TEST_LOG_FILE_NAME, 'wt') as f:
                    f.write(out_str)
                break

    env.close()
    return

# %% [markdown]
# ## Main steps

# %%
# TODO: CHANGE TO AGENT OBJECT
# create networks
policy_net = DQN(n_actions=4).to(device)
target_net = DQN(n_actions=4).to(device)
target_net.load_state_dict(policy_net.state_dict())
# Out:
# IncompatibleKeys(missing_keys=[], unexpected_keys=[])

# %%
# setup optimizer
optimizer = optim.Adam(policy_net.parameters(), lr=lr)

steps_done = 0

# create environment
env = gym.make(ENV_NAME)
env = make_env(env)

# initialize replay memory
memory = ReplayMemory(MEMORY_SIZE)

# Hyperdash experiment
exp = Experiment(EXP_NAME, capture_io=False)
print("Learning rate:{}".format(lr))
exp.param("Learning rate", lr)
exp.param("Environment", ENV_NAME)
exp.param("Batch size", BATCH_SIZE)
exp.param("Gamma", GAMMA)
exp.param("Episode start", EPS_START)
exp.param("Episode end", EPS_END)
exp.param("Episode decay", EPS_DECAY)
exp.param("Target update", TARGET_UPDATE)
exp.param("Render", str(RENDER))
exp.param("Initial memory", INITIAL_MEMORY)
exp.param("Memory size", MEMORY_SIZE)
# Out:
# Learning rate:0.0001
# { Learning rate: 0.0001 }
# { Environment: PongNoFrameskip-v4 }
# { Batch size: 32 }
# { Gamma: 0.99 }
# { Episode start: 1 }
# { Episode end: 0.02 }
# { Episode decay: 1000000 }
# { Target update: 1000 }
# { Render: False }
# { Initial memory: 10000 }
# { Memory size: 100000 }
# 100000

# %%
# train model
train(env, 400, exp)
exp.end()

torch.save(policy_net, "dqn_pong_model")

policy_net = torch.load("dqn_pong_model")
exp_test = Experiment(str(EXP_NAME + "_test_step"), capture_io=False)
test(env, 1, policy_net, exp_test, render=False)
exp_test.end()
# Out:
# | total_reword: -19.000000 |
#
# Total steps: 1160 	 Episode/Steps: 0/1159 	 Total reward: -19.0
#
# | total_reword: -18.000000 |
# Total steps: 2383 	 Episode/Steps: 1/1222 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 3404 	 Episode/Steps: 2/1020 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 4346 	 Episode/Steps: 3/941 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 5261 	 Episode/Steps: 4/914 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 6022 	 Episode/Steps: 5/760 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 6858 	 Episode/Steps: 6/835 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 7815 	 Episode/Steps: 7/956 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 8601 	 Episode/Steps: 8/785 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 9483 	 Episode/Steps: 9/881 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 10458 	 Episode/Steps: 10/974 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 11386 	 Episode/Steps: 11/927 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 12273 	 Episode/Steps: 12/886 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 13330 	 Episode/Steps: 13/1056 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 14361 	 Episode/Steps: 14/1030 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 15312 	 Episode/Steps: 15/950 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 16277 	 Episode/Steps: 16/964 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 17144 	 Episode/Steps: 17/866 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 17978 	 Episode/Steps: 18/833 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 18735 	 Episode/Steps: 19/756 	 Total reward: -21.0
# | total_reword: -21.000000 |
#
# Total steps: 19557 	 Episode/Steps: 20/821 	 Total reward: -21.0
#
# | total_reword: -20.000000 |
# Total steps: 20518 	 Episode/Steps: 21/960 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 21364 	 Episode/Steps: 22/845 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 22198 	 Episode/Steps: 23/833 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 23139 	 Episode/Steps: 24/940 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 23987 	 Episode/Steps: 25/847 	 Total reward: -21.0
# | total_reword: -18.000000 |
# Total steps: 25147 	 Episode/Steps: 26/1159 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 26038 	 Episode/Steps: 27/890 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 26946 	 Episode/Steps: 28/907 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 27983 	 Episode/Steps: 29/1036 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 28803 	 Episode/Steps: 30/819 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 29894 	 Episode/Steps: 31/1090 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 30652 	 Episode/Steps: 32/757 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 31837 	 Episode/Steps: 33/1184 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 32894 	 Episode/Steps: 34/1056 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 33817 	 Episode/Steps: 35/922 	 Total reward: -20.0
# | total_reword: -17.000000 |
# Total steps: 34954 	 Episode/Steps: 36/1136 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 35925 	 Episode/Steps: 37/970 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 36807 	 Episode/Steps: 38/881 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 37747 	 Episode/Steps: 39/939 	 Total reward: -21.0
# | total_reword: -21.000000 |
#
# Total steps: 38533 	 Episode/Steps: 40/785 	 Total reward: -21.0
#
# | total_reword: -21.000000 |
# Total steps: 39438 	 Episode/Steps: 41/904 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 40316 	 Episode/Steps: 42/877 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 41193 	 Episode/Steps: 43/876 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 42069 	 Episode/Steps: 44/875 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 42989 	 Episode/Steps: 45/919 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 43968 	 Episode/Steps: 46/978 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 44864 	 Episode/Steps: 47/895 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 45862 	 Episode/Steps: 48/997 	 Total reward: -21.0
# | total_reword: -18.000000 |
# Total steps: 47029 	 Episode/Steps: 49/1166 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 47953 	 Episode/Steps: 50/923 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 48851 	 Episode/Steps: 51/897 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 50006 	 Episode/Steps: 52/1154 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 50970 	 Episode/Steps: 53/963 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 51937 	 Episode/Steps: 54/966 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 52785 	 Episode/Steps: 55/847 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 53727 	 Episode/Steps: 56/941 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 54564 	 Episode/Steps: 57/836 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 55445 	 Episode/Steps: 58/880 	 Total reward: -21.0
# | total_reword: -18.000000 |
# Total steps: 56673 	 Episode/Steps: 59/1227 	 Total reward: -18.0
# | total_reword: -20.000000 |
#
# Total steps: 57797 	 Episode/Steps: 60/1123 	 Total reward: -20.0
#
# | total_reword: -18.000000 |
# Total steps: 58930 	 Episode/Steps: 61/1132 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 59811 	 Episode/Steps: 62/880 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 60692 	 Episode/Steps: 63/880 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 61687 	 Episode/Steps: 64/994 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 62917 	 Episode/Steps: 65/1229 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 63732 	 Episode/Steps: 66/814 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 64647 	 Episode/Steps: 67/914 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 65724 	 Episode/Steps: 68/1076 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 66498 	 Episode/Steps: 69/773 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 67535 	 Episode/Steps: 70/1036 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 68767 	 Episode/Steps: 71/1231 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 69734 	 Episode/Steps: 72/966 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 70668 	 Episode/Steps: 73/933 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 71728 	 Episode/Steps: 74/1059 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 72607 	 Episode/Steps: 75/878 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 73587 	 Episode/Steps: 76/979 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 74706 	 Episode/Steps: 77/1118 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 75634 	 Episode/Steps: 78/927 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 76590 	 Episode/Steps: 79/955 	 Total reward: -21.0
# | total_reword: -20.000000 |
#
# Total steps: 77625 	 Episode/Steps: 80/1034 	 Total reward: -20.0
#
# | total_reword: -19.000000 |
# Total steps: 78789 	 Episode/Steps: 81/1163 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 79671 	 Episode/Steps: 82/881 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 80666 	 Episode/Steps: 83/994 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 81872 	 Episode/Steps: 84/1205 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 82748 	 Episode/Steps: 85/875 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 84039 	 Episode/Steps: 86/1290 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 85112 	 Episode/Steps: 87/1072 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 86333 	 Episode/Steps: 88/1220 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 87409 	 Episode/Steps: 89/1075 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 88227 	 Episode/Steps: 90/817 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 89183 	 Episode/Steps: 91/955 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 90504 	 Episode/Steps: 92/1320 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 91349 	 Episode/Steps: 93/844 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 92314 	 Episode/Steps: 94/964 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 93412 	 Episode/Steps: 95/1097 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 94602 	 Episode/Steps: 96/1189 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 95662 	 Episode/Steps: 97/1059 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 96544 	 Episode/Steps: 98/881 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 97480 	 Episode/Steps: 99/935 	 Total reward: -21.0
# | total_reword: -21.000000 |
#
# Total steps: 98302 	 Episode/Steps: 100/821 	 Total reward: -21.0
#
# | total_reword: -20.000000 |
# Total steps: 99338 	 Episode/Steps: 101/1035 	 Total reward: -20.0
# | total_reword: -17.000000 |
# Total steps: 100626 	 Episode/Steps: 102/1287 	 Total reward: -17.0
# | total_reword: -21.000000 |
# Total steps: 101592 	 Episode/Steps: 103/965 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 102931 	 Episode/Steps: 104/1338 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 103829 	 Episode/Steps: 105/897 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 105053 	 Episode/Steps: 106/1223 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 106387 	 Episode/Steps: 107/1333 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 107362 	 Episode/Steps: 108/974 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 108278 	 Episode/Steps: 109/915 	 Total reward: -20.0
# | total_reword: -17.000000 |
# Total steps: 109580 	 Episode/Steps: 110/1301 	 Total reward: -17.0
# | total_reword: -21.000000 |
# Total steps: 110463 	 Episode/Steps: 111/882 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 111282 	 Episode/Steps: 112/818 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 112403 	 Episode/Steps: 113/1120 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 113563 	 Episode/Steps: 114/1159 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 114798 	 Episode/Steps: 115/1234 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 115788 	 Episode/Steps: 116/989 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 116900 	 Episode/Steps: 117/1111 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 118058 	 Episode/Steps: 118/1157 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 119059 	 Episode/Steps: 119/1000 	 Total reward: -21.0
# | total_reword: -21.000000 |
#
# Total steps: 119879 	 Episode/Steps: 120/819 	 Total reward: -21.0
#
# | total_reword: -20.000000 |
# Total steps: 120908 	 Episode/Steps: 121/1028 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 121910 	 Episode/Steps: 122/1001 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 122936 	 Episode/Steps: 123/1025 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 123994 	 Episode/Steps: 124/1057 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 125197 	 Episode/Steps: 125/1202 	 Total reward: -19.0
# | total_reword: -18.000000 |
# Total steps: 126570 	 Episode/Steps: 126/1372 	 Total reward: -18.0
# | total_reword: -20.000000 |
# Total steps: 127628 	 Episode/Steps: 127/1057 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 128825 	 Episode/Steps: 128/1196 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 129900 	 Episode/Steps: 129/1074 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 130850 	 Episode/Steps: 130/949 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 131987 	 Episode/Steps: 131/1136 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 133047 	 Episode/Steps: 132/1059 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 133990 	 Episode/Steps: 133/942 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 135006 	 Episode/Steps: 134/1015 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 136251 	 Episode/Steps: 135/1244 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 137289 	 Episode/Steps: 136/1037 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 138107 	 Episode/Steps: 137/817 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 139158 	 Episode/Steps: 138/1050 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 140353 	 Episode/Steps: 139/1194 	 Total reward: -20.0
# | total_reword: -20.000000 |
#
# Total steps: 141629 	 Episode/Steps: 140/1275 	 Total reward: -20.0
#
# | total_reword: -20.000000 |
# Total steps: 142933 	 Episode/Steps: 141/1303 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 143948 	 Episode/Steps: 142/1014 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 144933 	 Episode/Steps: 143/984 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 146227 	 Episode/Steps: 144/1293 	 Total reward: -18.0
# | total_reword: -19.000000 |
# Total steps: 147525 	 Episode/Steps: 145/1297 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 148495 	 Episode/Steps: 146/969 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 149684 	 Episode/Steps: 147/1188 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 150534 	 Episode/Steps: 148/849 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 151730 	 Episode/Steps: 149/1195 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 152829 	 Episode/Steps: 150/1098 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 153705 	 Episode/Steps: 151/875 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 154786 	 Episode/Steps: 152/1080 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 155821 	 Episode/Steps: 153/1034 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 156775 	 Episode/Steps: 154/953 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 157783 	 Episode/Steps: 155/1007 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 158691 	 Episode/Steps: 156/907 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 159948 	 Episode/Steps: 157/1256 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 161005 	 Episode/Steps: 158/1056 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 162038 	 Episode/Steps: 159/1032 	 Total reward: -20.0
# | total_reword: -21.000000 |
#
# Total steps: 162980 	 Episode/Steps: 160/941 	 Total reward: -21.0
#
# | total_reword: -20.000000 |
# Total steps: 164023 	 Episode/Steps: 161/1042 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 164799 	 Episode/Steps: 162/775 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 165709 	 Episode/Steps: 163/909 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 166662 	 Episode/Steps: 164/952 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 168025 	 Episode/Steps: 165/1362 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 169213 	 Episode/Steps: 166/1187 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 170480 	 Episode/Steps: 167/1266 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 171722 	 Episode/Steps: 168/1241 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 172728 	 Episode/Steps: 169/1005 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 174003 	 Episode/Steps: 170/1274 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 175359 	 Episode/Steps: 171/1355 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 176286 	 Episode/Steps: 172/926 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 177269 	 Episode/Steps: 173/982 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 178220 	 Episode/Steps: 174/950 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 179310 	 Episode/Steps: 175/1089 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 180285 	 Episode/Steps: 176/974 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 181554 	 Episode/Steps: 177/1268 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 182600 	 Episode/Steps: 178/1045 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 183768 	 Episode/Steps: 179/1167 	 Total reward: -21.0
# | total_reword: -21.000000 |
#
# Total steps: 184854 	 Episode/Steps: 180/1085 	 Total reward: -21.0
#
# | total_reword: -19.000000 |
# Total steps: 185991 	 Episode/Steps: 181/1136 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 186906 	 Episode/Steps: 182/914 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 188120 	 Episode/Steps: 183/1213 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 189563 	 Episode/Steps: 184/1442 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 190579 	 Episode/Steps: 185/1015 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 191664 	 Episode/Steps: 186/1084 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 193084 	 Episode/Steps: 187/1419 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 194024 	 Episode/Steps: 188/939 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 195058 	 Episode/Steps: 189/1033 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 196176 	 Episode/Steps: 190/1117 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 197649 	 Episode/Steps: 191/1472 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 198798 	 Episode/Steps: 192/1148 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 199905 	 Episode/Steps: 193/1106 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 201073 	 Episode/Steps: 194/1167 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 202112 	 Episode/Steps: 195/1038 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 203329 	 Episode/Steps: 196/1216 	 Total reward: -18.0
# | total_reword: -19.000000 |
# Total steps: 204551 	 Episode/Steps: 197/1221 	 Total reward: -19.0
# | total_reword: -16.000000 |
# Total steps: 206095 	 Episode/Steps: 198/1543 	 Total reward: -16.0
# | total_reword: -21.000000 |
# Total steps: 207187 	 Episode/Steps: 199/1091 	 Total reward: -21.0
# | total_reword: -21.000000 |
#
# Total steps: 208660 	 Episode/Steps: 200/1472 	 Total reward: -21.0
#
# | total_reword: -19.000000 |
# Total steps: 209890 	 Episode/Steps: 201/1229 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 211143 	 Episode/Steps: 202/1252 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 212265 	 Episode/Steps: 203/1121 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 213565 	 Episode/Steps: 204/1299 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 214653 	 Episode/Steps: 205/1087 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 215908 	 Episode/Steps: 206/1254 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 217110 	 Episode/Steps: 207/1201 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 218358 	 Episode/Steps: 208/1247 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 219712 	 Episode/Steps: 209/1353 	 Total reward: -18.0
# | total_reword: -16.000000 |
# Total steps: 221597 	 Episode/Steps: 210/1884 	 Total reward: -16.0
# | total_reword: -21.000000 |
# Total steps: 223019 	 Episode/Steps: 211/1421 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 224404 	 Episode/Steps: 212/1384 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 225375 	 Episode/Steps: 213/970 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 226585 	 Episode/Steps: 214/1209 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 227688 	 Episode/Steps: 215/1102 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 228753 	 Episode/Steps: 216/1064 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 230057 	 Episode/Steps: 217/1303 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 231216 	 Episode/Steps: 218/1158 	 Total reward: -19.0
# | total_reword: -18.000000 |
# Total steps: 232638 	 Episode/Steps: 219/1421 	 Total reward: -18.0
# | total_reword: -18.000000 |
#
# Total steps: 234268 	 Episode/Steps: 220/1629 	 Total reward: -18.0
#
# | total_reword: -19.000000 |
# Total steps: 235671 	 Episode/Steps: 221/1402 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 236956 	 Episode/Steps: 222/1284 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 238133 	 Episode/Steps: 223/1176 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 239467 	 Episode/Steps: 224/1333 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 240840 	 Episode/Steps: 225/1372 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 242118 	 Episode/Steps: 226/1277 	 Total reward: -18.0
# | total_reword: -20.000000 |
# Total steps: 243512 	 Episode/Steps: 227/1393 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 244973 	 Episode/Steps: 228/1460 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 246074 	 Episode/Steps: 229/1100 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 247347 	 Episode/Steps: 230/1272 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 248577 	 Episode/Steps: 231/1229 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 249589 	 Episode/Steps: 232/1011 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 250828 	 Episode/Steps: 233/1238 	 Total reward: -20.0
# | total_reword: -16.000000 |
# Total steps: 252487 	 Episode/Steps: 234/1658 	 Total reward: -16.0
# | total_reword: -19.000000 |
# Total steps: 253673 	 Episode/Steps: 235/1185 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 254977 	 Episode/Steps: 236/1303 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 256167 	 Episode/Steps: 237/1189 	 Total reward: -19.0
# | total_reword: -18.000000 |
# Total steps: 257380 	 Episode/Steps: 238/1212 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 258468 	 Episode/Steps: 239/1087 	 Total reward: -21.0
# | total_reword: -17.000000 |
#
# Total steps: 260090 	 Episode/Steps: 240/1621 	 Total reward: -17.0
#
# | total_reword: -19.000000 |
# Total steps: 261267 	 Episode/Steps: 241/1176 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 262358 	 Episode/Steps: 242/1090 	 Total reward: -19.0
# | total_reword: -17.000000 |
# Total steps: 263862 	 Episode/Steps: 243/1503 	 Total reward: -17.0
# | total_reword: -19.000000 |
# Total steps: 265412 	 Episode/Steps: 244/1549 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 266643 	 Episode/Steps: 245/1230 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 268060 	 Episode/Steps: 246/1416 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 269334 	 Episode/Steps: 247/1273 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 270459 	 Episode/Steps: 248/1124 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 271815 	 Episode/Steps: 249/1355 	 Total reward: -19.0
# | total_reword: -18.000000 |
# Total steps: 273362 	 Episode/Steps: 250/1546 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 274453 	 Episode/Steps: 251/1090 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 275640 	 Episode/Steps: 252/1186 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 276788 	 Episode/Steps: 253/1147 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 278269 	 Episode/Steps: 254/1480 	 Total reward: -18.0
# | total_reword: -17.000000 |
# Total steps: 280417 	 Episode/Steps: 255/2147 	 Total reward: -17.0
# | total_reword: -21.000000 |
# Total steps: 281665 	 Episode/Steps: 256/1247 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 282752 	 Episode/Steps: 257/1086 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 283842 	 Episode/Steps: 258/1089 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 285214 	 Episode/Steps: 259/1371 	 Total reward: -20.0
# | total_reword: -18.000000 |
#
# Total steps: 286740 	 Episode/Steps: 260/1525 	 Total reward: -18.0
#
# | total_reword: -19.000000 |
# Total steps: 288397 	 Episode/Steps: 261/1656 	 Total reward: -19.0
# | total_reword: -18.000000 |
# Total steps: 289901 	 Episode/Steps: 262/1503 	 Total reward: -18.0
# | total_reword: -19.000000 |
# Total steps: 291409 	 Episode/Steps: 263/1507 	 Total reward: -19.0
# | total_reword: -17.000000 |
# Total steps: 292848 	 Episode/Steps: 264/1438 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 293970 	 Episode/Steps: 265/1121 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 295307 	 Episode/Steps: 266/1336 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 296493 	 Episode/Steps: 267/1185 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 297516 	 Episode/Steps: 268/1022 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 298421 	 Episode/Steps: 269/904 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 299728 	 Episode/Steps: 270/1306 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 300913 	 Episode/Steps: 271/1184 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 301989 	 Episode/Steps: 272/1075 	 Total reward: -19.0
# | total_reword: -17.000000 |
# Total steps: 303516 	 Episode/Steps: 273/1526 	 Total reward: -17.0
# | total_reword: -18.000000 |
# Total steps: 304704 	 Episode/Steps: 274/1187 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 305798 	 Episode/Steps: 275/1093 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 306998 	 Episode/Steps: 276/1199 	 Total reward: -21.0
# | total_reword: -17.000000 |
# Total steps: 308376 	 Episode/Steps: 277/1377 	 Total reward: -17.0
# | total_reword: -18.000000 |
# Total steps: 309629 	 Episode/Steps: 278/1252 	 Total reward: -18.0
# | total_reword: -16.000000 |
# Total steps: 311192 	 Episode/Steps: 279/1562 	 Total reward: -16.0
# | total_reword: -18.000000 |
#
# Total steps: 312653 	 Episode/Steps: 280/1460 	 Total reward: -18.0
#
# | total_reword: -18.000000 |
# Total steps: 313937 	 Episode/Steps: 281/1283 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 314816 	 Episode/Steps: 282/878 	 Total reward: -21.0
# | total_reword: -17.000000 |
# Total steps: 316253 	 Episode/Steps: 283/1436 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 317374 	 Episode/Steps: 284/1120 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 318278 	 Episode/Steps: 285/903 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 319569 	 Episode/Steps: 286/1290 	 Total reward: -19.0
# | total_reword: -17.000000 |
# Total steps: 320977 	 Episode/Steps: 287/1407 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 322190 	 Episode/Steps: 288/1212 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 323722 	 Episode/Steps: 289/1531 	 Total reward: -18.0
# | total_reword: -20.000000 |
# Total steps: 325122 	 Episode/Steps: 290/1399 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 326445 	 Episode/Steps: 291/1322 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 327721 	 Episode/Steps: 292/1275 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 328986 	 Episode/Steps: 293/1264 	 Total reward: -19.0
# | total_reword: -18.000000 |
# Total steps: 330148 	 Episode/Steps: 294/1161 	 Total reward: -18.0
# | total_reword: -18.000000 |
# Total steps: 331618 	 Episode/Steps: 295/1469 	 Total reward: -18.0
# | total_reword: -19.000000 |
# Total steps: 332993 	 Episode/Steps: 296/1374 	 Total reward: -19.0
# | total_reword: -16.000000 |
# Total steps: 334605 	 Episode/Steps: 297/1611 	 Total reward: -16.0
# | total_reword: -18.000000 |
# Total steps: 336198 	 Episode/Steps: 298/1592 	 Total reward: -18.0
# | total_reword: -19.000000 |
# Total steps: 337592 	 Episode/Steps: 299/1393 	 Total reward: -19.0
# | total_reword: -19.000000 |
#
# Total steps: 339075 	 Episode/Steps: 300/1482 	 Total reward: -19.0
#
# | total_reword: -20.000000 |
# Total steps: 340237 	 Episode/Steps: 301/1161 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 341946 	 Episode/Steps: 302/1708 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 343022 	 Episode/Steps: 303/1075 	 Total reward: -21.0
# | total_reword: -18.000000 |
# Total steps: 344476 	 Episode/Steps: 304/1453 	 Total reward: -18.0
# | total_reword: -20.000000 |
# Total steps: 345765 	 Episode/Steps: 305/1288 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 347293 	 Episode/Steps: 306/1527 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 348294 	 Episode/Steps: 307/1000 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 349630 	 Episode/Steps: 308/1335 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 351077 	 Episode/Steps: 309/1446 	 Total reward: -19.0
# | total_reword: -17.000000 |
# Total steps: 352483 	 Episode/Steps: 310/1405 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 353672 	 Episode/Steps: 311/1188 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 355434 	 Episode/Steps: 312/1761 	 Total reward: -18.0
# | total_reword: -18.000000 |
# Total steps: 356953 	 Episode/Steps: 313/1518 	 Total reward: -18.0
# | total_reword: -18.000000 |
# Total steps: 358719 	 Episode/Steps: 314/1765 	 Total reward: -18.0
# | total_reword: -18.000000 |
# Total steps: 360185 	 Episode/Steps: 315/1465 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 361668 	 Episode/Steps: 316/1482 	 Total reward: -21.0
# | total_reword: -16.000000 |
# Total steps: 363500 	 Episode/Steps: 317/1831 	 Total reward: -16.0
# | total_reword: -18.000000 |
# Total steps: 365645 	 Episode/Steps: 318/2144 	 Total reward: -18.0
# | total_reword: -19.000000 |
# Total steps: 367019 	 Episode/Steps: 319/1373 	 Total reward: -19.0
# | total_reword: -21.000000 |
#
# Total steps: 368040 	 Episode/Steps: 320/1020 	 Total reward: -21.0
#
# | total_reword: -20.000000 |
# Total steps: 369111 	 Episode/Steps: 321/1070 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 371091 	 Episode/Steps: 322/1979 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 372484 	 Episode/Steps: 323/1392 	 Total reward: -21.0
# | total_reword: -17.000000 |
# Total steps: 374091 	 Episode/Steps: 324/1606 	 Total reward: -17.0
# | total_reword: -18.000000 |
# Total steps: 375715 	 Episode/Steps: 325/1623 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 376863 	 Episode/Steps: 326/1147 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 378295 	 Episode/Steps: 327/1431 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 379714 	 Episode/Steps: 328/1418 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 380910 	 Episode/Steps: 329/1195 	 Total reward: -21.0
# | total_reword: -18.000000 |
# Total steps: 382352 	 Episode/Steps: 330/1441 	 Total reward: -18.0
# | total_reword: -19.000000 |
# Total steps: 383663 	 Episode/Steps: 331/1310 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 384782 	 Episode/Steps: 332/1118 	 Total reward: -19.0
# | total_reword: -18.000000 |
# Total steps: 386121 	 Episode/Steps: 333/1338 	 Total reward: -18.0
# | total_reword: -19.000000 |
# Total steps: 387482 	 Episode/Steps: 334/1360 	 Total reward: -19.0
# | total_reword: -16.000000 |
# Total steps: 389463 	 Episode/Steps: 335/1980 	 Total reward: -16.0
# | total_reword: -19.000000 |
# Total steps: 390683 	 Episode/Steps: 336/1219 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 392212 	 Episode/Steps: 337/1528 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 393526 	 Episode/Steps: 338/1313 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 394739 	 Episode/Steps: 339/1212 	 Total reward: -20.0
# | total_reword: -19.000000 |
#
# Total steps: 396132 	 Episode/Steps: 340/1392 	 Total reward: -19.0
#
# | total_reword: -17.000000 |
# Total steps: 397281 	 Episode/Steps: 341/1148 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 398692 	 Episode/Steps: 342/1410 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 400378 	 Episode/Steps: 343/1685 	 Total reward: -18.0
# | total_reword: -20.000000 |
# Total steps: 401907 	 Episode/Steps: 344/1528 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 403547 	 Episode/Steps: 345/1639 	 Total reward: -18.0
# | total_reword: -20.000000 |
# Total steps: 405382 	 Episode/Steps: 346/1834 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 406888 	 Episode/Steps: 347/1505 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 408002 	 Episode/Steps: 348/1113 	 Total reward: -20.0
# | total_reword: -16.000000 |
# Total steps: 410433 	 Episode/Steps: 349/2430 	 Total reward: -16.0
# | total_reword: -17.000000 |
# Total steps: 411906 	 Episode/Steps: 350/1472 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 413230 	 Episode/Steps: 351/1323 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 414434 	 Episode/Steps: 352/1203 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 415935 	 Episode/Steps: 353/1500 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 417243 	 Episode/Steps: 354/1307 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 418744 	 Episode/Steps: 355/1500 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 420074 	 Episode/Steps: 356/1329 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 421434 	 Episode/Steps: 357/1359 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 423146 	 Episode/Steps: 358/1711 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 424640 	 Episode/Steps: 359/1493 	 Total reward: -20.0
# | total_reword: -19.000000 |
#
# Total steps: 425949 	 Episode/Steps: 360/1308 	 Total reward: -19.0
#
# | total_reword: -17.000000 |
# Total steps: 427754 	 Episode/Steps: 361/1804 	 Total reward: -17.0
# | total_reword: -21.000000 |
# Total steps: 428837 	 Episode/Steps: 362/1082 	 Total reward: -21.0
# | total_reword: -17.000000 |
# Total steps: 430711 	 Episode/Steps: 363/1873 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 432034 	 Episode/Steps: 364/1322 	 Total reward: -20.0
# | total_reword: -17.000000 |
# Total steps: 433805 	 Episode/Steps: 365/1770 	 Total reward: -17.0
# | total_reword: -16.000000 |
# Total steps: 435427 	 Episode/Steps: 366/1621 	 Total reward: -16.0
# | total_reword: -17.000000 |
# Total steps: 436992 	 Episode/Steps: 367/1564 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 438112 	 Episode/Steps: 368/1119 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 439839 	 Episode/Steps: 369/1726 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 441406 	 Episode/Steps: 370/1566 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 442677 	 Episode/Steps: 371/1270 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 444140 	 Episode/Steps: 372/1462 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 445548 	 Episode/Steps: 373/1407 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 446927 	 Episode/Steps: 374/1378 	 Total reward: -19.0
# | total_reword: -18.000000 |
# Total steps: 448646 	 Episode/Steps: 375/1718 	 Total reward: -18.0
# | total_reword: -19.000000 |
# Total steps: 450180 	 Episode/Steps: 376/1533 	 Total reward: -19.0
# | total_reword: -17.000000 |
# Total steps: 452296 	 Episode/Steps: 377/2115 	 Total reward: -17.0
# | total_reword: -15.000000 |
# Total steps: 454054 	 Episode/Steps: 378/1757 	 Total reward: -15.0
# | total_reword: -21.000000 |
# Total steps: 455430 	 Episode/Steps: 379/1375 	 Total reward: -21.0
# | total_reword: -20.000000 |
#
# Total steps: 456797 	 Episode/Steps: 380/1366 	 Total reward: -20.0
#
# | total_reword: -11.000000 |
# Total steps: 459578 	 Episode/Steps: 381/2780 	 Total reward: -11.0
# | total_reword: -15.000000 |
# Total steps: 461188 	 Episode/Steps: 382/1609 	 Total reward: -15.0
# | total_reword: -16.000000 |
# Total steps: 462869 	 Episode/Steps: 383/1680 	 Total reward: -16.0
# | total_reword: -20.000000 |
# Total steps: 463961 	 Episode/Steps: 384/1091 	 Total reward: -20.0
# | total_reword: -17.000000 |
# Total steps: 465412 	 Episode/Steps: 385/1450 	 Total reward: -17.0
# | total_reword: -17.000000 |
# Total steps: 467074 	 Episode/Steps: 386/1661 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 468408 	 Episode/Steps: 387/1333 	 Total reward: -20.0
# | total_reword: -17.000000 |
# Total steps: 469794 	 Episode/Steps: 388/1385 	 Total reward: -17.0
# | total_reword: -16.000000 |
# Total steps: 471520 	 Episode/Steps: 389/1725 	 Total reward: -16.0
# | total_reword: -17.000000 |
# Total steps: 473027 	 Episode/Steps: 390/1506 	 Total reward: -17.0
# | total_reword: -20.000000 |
# Total steps: 474155 	 Episode/Steps: 391/1127 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 475308 	 Episode/Steps: 392/1152 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 476621 	 Episode/Steps: 393/1312 	 Total reward: -19.0
# | total_reword: -19.000000 |
# Total steps: 477946 	 Episode/Steps: 394/1324 	 Total reward: -19.0
# | total_reword: -17.000000 |
# Total steps: 479910 	 Episode/Steps: 395/1963 	 Total reward: -17.0
# | total_reword: -19.000000 |
# Total steps: 481068 	 Episode/Steps: 396/1157 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 482591 	 Episode/Steps: 397/1522 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 483714 	 Episode/Steps: 398/1122 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 485169 	 Episode/Steps: 399/1454 	 Total reward: -20.0
# This run of PongNoFrameskip-v4_1568005544 ran for 1:08:55 and logs are available locally at: /root/.hyperdash/logs/pongnoframeskip-v4-1568005544/pongnoframeskip-v4-1568005544_2019-09-09t05-06-12-920301.log
# /usr/local/lib/python3.6/dist-packages/torch/serialization.py:256: UserWarning: Couldn't retrieve source code for container of type DQN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Finished Episode 0 with reward -16.0
# Finished Episode 0 with reward -16.0
# This run of PongNoFrameskip-v4_1568005544_test_step ran for 0:00:08 and logs are available locally at: /root/.hyperdash/logs/pongnoframeskip-v4-1568005544-test-step/pongnoframeskip-v4-1568005544-test-step_2019-09-09t06-15-09-278912.log

# %% [markdown]
# ## Video vidualization

# %%
# !apt-get install xvfb
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 8 not upgraded.
# Need to get 0 B/783 kB of archives.
# After this operation, 2,266 kB of additional disk space will be used.
# Selecting previously unselected package xvfb.
# (Reading database ... 131183 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.3_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.3) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.3) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()
os.environ["DISPLAY"] = ":" + str(display.display) + "." + str(display.screen)

# %%
def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
        <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return IPython.display.HTML(tag)

# %%
embed_mp4("/content/videos/dqn_pong_video/openaigym.video.0.123.video000000.mp4")
# Out:
#     <video width="640" height="480" controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>

# %%
# !mkdir /content/drive/My\ Drive/Colab\ Notebooks/MT/pong_videos_1568005544

# %%
# !mv ./PongNoFrameskip-v4_*.log /content/drive/My\ Drive/Colab\ Notebooks/MT/pong_videos_1568005544/
# !mv ./dqn_pong_model /content/drive/My\ Drive/Colab\ Notebooks/MT/pong_videos_1568005544/
# !mv ./videos /content/drive/My\ Drive/Colab\ Notebooks/MT/pong_videos_1568005544/

# %% [markdown]
# ## Note
#
# * Randomの初期値依存性のみで傾向がつかめるならGAで初期値最適化すると良い
# * 学習結果が悪かったモデルについて追加で学習した場合結果はどうなるかの確認
#
# ---
#
# * Multi-agentはQueue管理で
# * ManegerはDe-Queueし，実行したAgentの結果から良いものを選ぶ
# * A2Cと異なるのか? (AgentとEnvのセットをどう扱うのか?)
# * Durable valueを削る条件
#     - 一定回数Rewardが上昇しない場合Durabilityが減少する?
#     - 予めDurabilityを高めに設定しておき，1episode前より上昇しない場合Durabilityを削る
#     - Durabilityが0にならないように調整する関数が必要?
#     - 単純にDurabilityを削って良い条件(Hyperparameter set)を探索する手法とする?

# %% [markdown]
# ## Extended training step
#
# Now we extend the training step.
# Load 400 episodes trainded model.

# %%
policy_net = torch.load("/content/drive/My Drive/Colab Notebooks/MT/pong_videos_1568005544/dqn_pong_model")
target_net = DQN(n_actions=4).to(device)
target_net.load_state_dict(policy_net.state_dict())

# setup optimizer
optimizer = optim.Adam(policy_net.parameters(), lr=lr)

steps_done = 0

# create environment
env = gym.make(ENV_NAME)
env = make_env(env)

# initialize replay memory
memory = ReplayMemory(MEMORY_SIZE)

EXP_NAME = "PongNoFrameskip-v4_1568005544_extended"

# Hyperdash experiment
exp = Experiment(EXP_NAME, capture_io=False)
print("Learning rate:{}".format(lr))
exp.param("Learning rate", lr)
exp.param("Environment", ENV_NAME)
exp.param("Batch size", BATCH_SIZE)
exp.param("Gamma", GAMMA)
exp.param("Episode start", EPS_START)
exp.param("Episode end", EPS_END)
exp.param("Episode decay", EPS_DECAY)
exp.param("Target update", TARGET_UPDATE)
exp.param("Render", str(RENDER))
exp.param("Initial memory", INITIAL_MEMORY)
exp.param("Memory size", MEMORY_SIZE)
# Out:
# Learning rate:0.0001
# { Learning rate: 0.0001 }
# { Environment: PongNoFrameskip-v4 }
# { Batch size: 32 }
# { Gamma: 0.99 }
# { Episode start: 1 }
# { Episode end: 0.02 }
# { Episode decay: 1000000 }
# { Target update: 1000 }
# { Render: False }
# { Initial memory: 10000 }
# { Memory size: 100000 }
# 100000

# %%
TRAIN_LOG_FILE_NAME = "/content/drive/My Drive/Colab Notebooks/MT/Runs/PongNoFrameskip-v4_1568005544_extended/" + ENV_NAME + "_train_" + time_stamp + ".log"
TEST_LOG_FILE_NAME = "/content/drive/My Drive/Colab Notebooks/MT/Runs/PongNoFrameskip-v4_1568005544_extended/" + ENV_NAME + "_test_" + time_stamp + ".log"

# %%
train(env, 400, exp)
exp.end()
torch.save(policy_net, "/content/drive/My Drive/Colab Notebooks/MT/Runs/PongNoFrameskip-v4_1568005544_extended/dqn_pong_model")
policy_net = torch.load("/content/drive/My Drive/Colab Notebooks/MT/Runs/PongNoFrameskip-v4_1568005544_extended/dqn_pong_model")
exp_test = Experiment(str(EXP_NAME + "_test_step"), capture_io=False)
test(env, 1, policy_net, exp_test, render=False)
exp_test.end()
# Out:
# | total_reword: -21.000000 |
#
# Total steps: 905 	 Episode/Steps: 0/904 	 Total reward: -21.0
#
# | total_reword: -20.000000 |
# Total steps: 1926 	 Episode/Steps: 1/1020 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 2919 	 Episode/Steps: 2/992 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 3951 	 Episode/Steps: 3/1031 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 5042 	 Episode/Steps: 4/1090 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 6044 	 Episode/Steps: 5/1001 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 6988 	 Episode/Steps: 6/943 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 7744 	 Episode/Steps: 7/755 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 8746 	 Episode/Steps: 8/1001 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 9655 	 Episode/Steps: 9/908 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 10662 	 Episode/Steps: 10/1006 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 11645 	 Episode/Steps: 11/982 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 12970 	 Episode/Steps: 12/1324 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 13848 	 Episode/Steps: 13/877 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 14670 	 Episode/Steps: 14/821 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 15992 	 Episode/Steps: 15/1321 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 16964 	 Episode/Steps: 16/971 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 18159 	 Episode/Steps: 17/1194 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 19005 	 Episode/Steps: 18/845 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 19939 	 Episode/Steps: 19/933 	 Total reward: -21.0
# | total_reword: -21.000000 |
#
# Total steps: 20726 	 Episode/Steps: 20/786 	 Total reward: -21.0
#
# | total_reword: -19.000000 |
# Total steps: 21776 	 Episode/Steps: 21/1049 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 22597 	 Episode/Steps: 22/820 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 23353 	 Episode/Steps: 23/755 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 24303 	 Episode/Steps: 24/949 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 25064 	 Episode/Steps: 25/760 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 25942 	 Episode/Steps: 26/877 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 27146 	 Episode/Steps: 27/1203 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 28116 	 Episode/Steps: 28/969 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 28949 	 Episode/Steps: 29/832 	 Total reward: -20.0
# | total_reword: -18.000000 |
# Total steps: 30089 	 Episode/Steps: 30/1139 	 Total reward: -18.0
# | total_reword: -21.000000 |
# Total steps: 31000 	 Episode/Steps: 31/910 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 32000 	 Episode/Steps: 32/999 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 32845 	 Episode/Steps: 33/844 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 33661 	 Episode/Steps: 34/815 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 34648 	 Episode/Steps: 35/986 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 35654 	 Episode/Steps: 36/1005 	 Total reward: -19.0
# | total_reword: -20.000000 |
# Total steps: 36655 	 Episode/Steps: 37/1000 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 37476 	 Episode/Steps: 38/820 	 Total reward: -21.0
# | total_reword: -19.000000 |
# Total steps: 38529 	 Episode/Steps: 39/1052 	 Total reward: -19.0
# | total_reword: -21.000000 |
#
# Total steps: 39410 	 Episode/Steps: 40/880 	 Total reward: -21.0
#
# | total_reword: -19.000000 |
# Total steps: 40628 	 Episode/Steps: 41/1217 	 Total reward: -19.0
# | total_reword: -21.000000 |
# Total steps: 41745 	 Episode/Steps: 42/1116 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 42767 	 Episode/Steps: 43/1021 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 43653 	 Episode/Steps: 44/885 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 44623 	 Episode/Steps: 45/969 	 Total reward: -20.0
# | total_reword: -20.000000 |
# Total steps: 45672 	 Episode/Steps: 46/1048 	 Total reward: -20.0
# | total_reword: -21.000000 |
# Total steps: 46674 	 Episode/Steps: 47/1001 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 47534 	 Episode/Steps: 48/859 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 48320 	 Episode/Steps: 49/785 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 49379 	 Episode/Steps: 50/1058 	 Total reward: -20.0
# | total_reword: -19.000000 |
# Total steps: 50673 	 Episode/Steps: 51/1293 	 Total reward: -19.0
# | total_reword: -17.000000 |
# Total steps: 52543 	 Episode/Steps: 52/1869 	 Total reward: -17.0
# | total_reword: -21.000000 |
# Total steps: 53350 	 Episode/Steps: 53/806 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 54193 	 Episode/Steps: 54/842 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 55192 	 Episode/Steps: 55/998 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 56403 	 Episode/Steps: 56/1210 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 57191 	 Episode/Steps: 57/787 	 Total reward: -21.0
# | total_reword: -21.000000 |
# Total steps: 58118 	 Episode/Steps: 58/926 	 Total reward: -21.0
# | total_reword: -20.000000 |
# Total steps: 59034 	 Episode/Steps: 59/915 	 Total reward: -20.0
# | total_reword: -21.000000 |
#
# Total steps: 59917 	 Episode/Steps: 60/882 	 Total reward: -21.0
#
# | total_reword: -20.000000 |
# Total steps: 61147 	 Episode/Steps: 61/1229 	 Total reward: -20.0
